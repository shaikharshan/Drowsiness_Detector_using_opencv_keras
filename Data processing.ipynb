# %%
import os
import shutil
import glob
from tqdm import tqdm

# %%
RAW_DATA_DIR = 'D:\ML_projects\mrlEyes_2018_01'
for dirname,filepath,filenames in os.walk(RAW_DATA_DIR):
    for i in tqdm([f for f in filenames if f.endswith('.png')]):
                   if i.split('_')[4]=='0':
                       shutil.copy(src=dirname+'/'+i,dst=r'D:\ML_projects\project_data\close eyes')
                   elif i.split('_')[4]=='1':
                       shutil.copy(src=dirname+'/'+i,dst=r'D:\ML_projects\project_data\open eyes')
# Out:
# 0it [00:00, ?it/s]
# ...
# 100%|████████████████████████████████████████████████████████████████████████████| 10257/10257 [02:04<00:00, 82.27it/s]

# %%
# We will implement Transfer Learning in this i.e use vgg-16 model which is already trained on ~1000 classes.
